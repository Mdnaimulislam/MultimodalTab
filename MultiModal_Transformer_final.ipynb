# %% [markdown]
# # Loading Multimodal Data

# %%
# !git clone https://Mdnaimulislam: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@github.com/Mdnaimulislam/MultimodalTab.git
# Out:
# Cloning into 'MultimodalTab'...
# remote: Enumerating objects: 50, done.
# remote: Counting objects: 100% (50/50), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 50 (delta 21), reused 21 (delta 8), pack-reused 0
# Unpacking objects: 100% (50/50), done.

# %%
# !pip install transformers==3.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 884 kB 34.0 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 41.2 MB/s
# ...
#      |████████████████████████████████| 880 kB 68.1 MB/s
# ...
#      |████████████████████████████████| 3.0 MB 57.7 MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=519d158e26fa8a39c16e324d5343170337647e0ff485c0193d57aa2fda3ba744
#   Stored in directory: /root/.cache/pip/wheels/87/39/dd/a83eeef36d0bf98e7a4d1933a4ad2d660295a40613079bafc9
# Successfully built sacremoses
# ...

# %%
import pandas as pd
import numpy as np
import random

# %% [markdown]
# # Load multimodal tabular data

# %% [markdown]
# # Demographic

# %%
import pandas as pd
from transformers import AutoTokenizer,  set_seed
from MultimodalTab.load_multimodal_tabular_data import load_data_into_folds
set_seed(1234)
text_cols = ['heart_rate_rhc']
label_col = 'death_1y' 
categorical_cols = ['baseline_prevalent','mri_order','sex', 'ethnicity','pah_subcategory','final_primary_ph_diagnosis','final_primary_diagnosis_subcategory','who_functional_class','pericardial_effusion']
numerical_cols = ['age','heart_rate_rhc',
 'walking_distance']
label_list = ['Not Died', 'Died'] # what each label class represents
# make sure NaN values for cat columns are filled before passing to load_data
#for c in categorical_cols:  
   #train_df.loc[:, c] = train_df.loc[:, c].astype(str).fillna("-9999999")
   #test_df.loc[:, c] = test_df.loc[:, c].astype(str).fillna("-9999999")

# %% [markdown]
# # Echo Report (Categorical)

# %%
import pandas as pd
from transformers import AutoTokenizer,  set_seed
from MultimodalTab.load_multimodal_tabular_data import load_data_into_folds
set_seed(1234)
text_cols = ['Aortic regurgitation']
label_col = 'death_1y' 
categorical_cols = ['LV function', 'RV function', 'LA appearance',
       'RA dilated?', 'RA pressure range', 'Mitral regurgitation',
       'Tricuspid regurgitation', 'If PR, specify', 'Aortic regurgitation']
numerical_cols = ['EDD (34-56mm)']
label_list = ['Not Died', 'Died'] # what each label class represents
# make sure NaN values for cat columns are filled before passing to load_data
#for c in categorical_cols:  
   #train_df.loc[:, c] = train_df.loc[:, c].astype(str).fillna("-9999999")
   #test_df.loc[:, c] = test_df.loc[:, c].astype(str).fillna("-9999999")

# %% [markdown]
# # Echo Report(Text )

# %%
import pandas as pd
from transformers import AutoTokenizer,  set_seed
from MultimodalTab.load_multimodal_tabular_data import load_data_into_folds
set_seed(1234)
text_cols = ["E/e' average",'Machine (old)', 'Reported by 1',
       'Reporting Doctor', 'Summary', 'Conclusion', 'Scanned by 1','Machine','Scanned by 2']
label_col = 'death_1y' 
categorical_cols = ['LV function']
numerical_cols = ['EDD (34-56mm)']
label_list = ['Not Died', 'Died'] # what each label class represents
# make sure NaN values for cat columns are filled before passing to load_data
#for c in categorical_cols:  
   #train_df.loc[:, c] = train_df.loc[:, c].astype(str).fillna("-9999999")
   #test_df.loc[:, c] = test_df.loc[:, c].astype(str).fillna("-9999999")

# %% [markdown]
# # Echo Report (Categorical + Text)

# %%
import pandas as pd
from transformers import AutoTokenizer,  set_seed
from MultimodalTab.load_multimodal_tabular_data import load_data_into_folds
set_seed(1234)
text_cols = ["E/e' average",'Machine (old)', 'Reported by 1',
       'Reporting Doctor', 'Summary', 'Conclusion', 'Scanned by 1','Machine','Scanned by 2']

label_col = 'death_1y' 
categorical_cols = ['LV function', 'RV function', 'LA appearance',
       'RA dilated?', 'RA pressure range', 'Mitral regurgitation',
       'Tricuspid regurgitation', 'If PR, specify', 'Aortic regurgitation']
numerical_cols = [
 'EDD (34-56mm)',
 'PW (<12mm)',
 'IVS (<12mm)',
 'Max vel A wave (0.2-0.6 m/sec)',
 'Max vel E wave (0.4-1.0 m/sec)',
 'Sinus of Valsalva',
 'E/A Ratio. (old)',
 'Peak PG',
 'E/A Ratio']
label_list = ['Not Died', 'Died'] # what each label class represents
# make sure NaN values for cat columns are filled before passing to load_data
#for c in categorical_cols:  
   #train_df.loc[:, c] = train_df.loc[:, c].astype(str).fillna("-9999999")
   #test_df.loc[:, c] = test_df.loc[:, c].astype(str).fillna("-9999999")

# %% [markdown]
# # Numerical Imaging Fetaures

# %%
import pandas as pd
from transformers import AutoTokenizer,  set_seed
from MultimodalTab.load_multimodal_tabular_data import load_data_into_folds
set_seed(1234)
text_cols = ['heart_rate_rhc']

label_col = 'death_1y' 
categorical_cols = ['heart_rate_rhc']
numerical_cols = [
 'heart_rate',
 'bsa',
 'lvedv',
 'lvedv_index',
 'lvesv',
 'lvesv_index',
 'lvsv',
 'lvsv_index',
 'lvco',
 'lvef',
 'lv_dia_mass',
 'lv_mass_index',
 'rvedv',
 'rvesv',
 'rvsv',
 'rvedv_index',
 'rvesv_index',
 'rvsv_index',
 'rvco',
 'rvef',
 'auto_lv_edv_index',
 'lv_edv',
 'auto_lv_esv_index',
 'lv_esv',
 'auto_lv_sv_index',
 'lv_sv',
 'auto_lv_co',
 'lv_ef',
 'auto_lv_mass_index',
 'lv_edm',
 'lv_esm',
 'auto_vmi',
 'auto_rv_edv_index',
 'rv_edv',
 'auto_rv_esv_index',
 'rv_esv',
 'auto_rv_sv_index',
 'rv_sv',
 'auto_rv_co',
 'rv_ef',
 'auto_rv_mass_index',
 'rv_edm',
 'rv_esm',
 'auto_percent_pred_rvesvi',
 'auto_percent_pred_rvedvi',
 'auto_percent_pred_rvef',
 'auto_percent_pred_rvsvi',
 'auto_percent_pred_rvedmi',
 'auto_percent_pred_lvesvi',
 'auto_percent_pred_lvedvi',
 'auto_percent_pred_lvef',
 'auto_percent_pred_lvsvi',
 'auto_percent_pred_lvedmi',
 'auto_percent_pred_vmi',
 'la_max_2ch_area',
 'la_min_2ch_area',
 'la_max_4ch_area',
 'la_min_4ch_area',
 'ra_max_2ch_area',
 'ra_min_2ch_area',
 'ra_max_4ch_area',
 'ra_min_4ch_area',
 'la_max_2ch_length',
 'la_min_2ch_length',
 'la_max_4ch_length',
 'la_min_4ch_length',
 'ra_max_2ch_length',
 'ra_min_2ch_length',
 'ra_max_4ch_length',
 'ra_min_4ch_length',
 'la_max_volume',
 'la_min_volume',
 'la_ejection_fraction',
 'la_long_axis_strain',
 'la_conduit_function',
 'ra_max_volume',
 'ra_min_volume',
 'ra_ejection_fraction',
 'ra_long_axis_strain',
 'ra_conduit_function',
 'la_max_volume_index',
 'la_min_volume_index',
 'la_ejection_fraction_index',
 'la_long_axis_strain_index',
 'ra_max_volume_index',
 'ra_min_volume_index',
 'ra_ejection_fraction_index',
 'ra_long_axis_strain_index',
 'pa_relative_area_change',
 'diastolic_pa_area',
 'systolic_pa_area',
 'pa_qflow_pos',
 'ao_qflow_positive']
label_list = ['Not Died', 'Died'] # what each label class represents
# make sure NaN values for cat columns are filled before passing to load_data
#for c in categorical_cols:  
   #train_df.loc[:, c] = train_df.loc[:, c].astype(str).fillna("-9999999")
   #test_df.loc[:, c] = test_df.loc[:, c].astype(str).fillna("-9999999")

# %% [markdown]
# # Imaging + Echo(Text)

# %%
import pandas as pd
from transformers import AutoTokenizer,  set_seed
from MultimodalTab.load_multimodal_tabular_data import load_data_into_folds
set_seed(1234)
text_cols = ["E/e' average",'Machine (old)', 'Reported by 1',
       'Reporting Doctor', 'Summary', 'Conclusion', 'Scanned by 1','Machine','Scanned by 2']

label_col = 'death_1y' 
categorical_cols = ['heart_rate_rhc']
numerical_cols = [
 'heart_rate',
 'bsa',
 'lvedv',
 'lvedv_index',
 'lvesv',
 'lvesv_index',
 'lvsv',
 'lvsv_index',
 'lvco',
 'lvef',
 'lv_dia_mass',
 'lv_mass_index',
 'rvedv',
 'rvesv',
 'rvsv',
 'rvedv_index',
 'rvesv_index',
 'rvsv_index',
 'rvco',
 'rvef',
 'auto_lv_edv_index',
 'lv_edv',
 'auto_lv_esv_index',
 'lv_esv',
 'auto_lv_sv_index',
 'lv_sv',
 'auto_lv_co',
 'lv_ef',
 'auto_lv_mass_index',
 'lv_edm',
 'lv_esm',
 'auto_vmi',
 'auto_rv_edv_index',
 'rv_edv',
 'auto_rv_esv_index',
 'rv_esv',
 'auto_rv_sv_index',
 'rv_sv',
 'auto_rv_co',
 'rv_ef',
 'auto_rv_mass_index',
 'rv_edm',
 'rv_esm',
 'auto_percent_pred_rvesvi',
 'auto_percent_pred_rvedvi',
 'auto_percent_pred_rvef',
 'auto_percent_pred_rvsvi',
 'auto_percent_pred_rvedmi',
 'auto_percent_pred_lvesvi',
 'auto_percent_pred_lvedvi',
 'auto_percent_pred_lvef',
 'auto_percent_pred_lvsvi',
 'auto_percent_pred_lvedmi',
 'auto_percent_pred_vmi',
 'la_max_2ch_area',
 'la_min_2ch_area',
 'la_max_4ch_area',
 'la_min_4ch_area',
 'ra_max_2ch_area',
 'ra_min_2ch_area',
 'ra_max_4ch_area',
 'ra_min_4ch_area',
 'la_max_2ch_length',
 'la_min_2ch_length',
 'la_max_4ch_length',
 'la_min_4ch_length',
 'ra_max_2ch_length',
 'ra_min_2ch_length',
 'ra_max_4ch_length',
 'ra_min_4ch_length',
 'la_max_volume',
 'la_min_volume',
 'la_ejection_fraction',
 'la_long_axis_strain',
 'la_conduit_function',
 'ra_max_volume',
 'ra_min_volume',
 'ra_ejection_fraction',
 'ra_long_axis_strain',
 'ra_conduit_function',
 'la_max_volume_index',
 'la_min_volume_index',
 'la_ejection_fraction_index',
 'la_long_axis_strain_index',
 'ra_max_volume_index',
 'ra_min_volume_index',
 'ra_ejection_fraction_index',
 'ra_long_axis_strain_index',
 'pa_relative_area_change',
 'diastolic_pa_area',
 'systolic_pa_area',
 'pa_qflow_pos',
 'ao_qflow_positive',
 'EDD (34-56mm)',
 'PW (<12mm)',
 'IVS (<12mm)',
 'Max vel A wave (0.2-0.6 m/sec)',
 'Max vel E wave (0.4-1.0 m/sec)',
 'Sinus of Valsalva',
 'E/A Ratio. (old)',
 'Peak PG',
 'E/A Ratio']
label_list = ['Not Died', 'Died'] # what each label class represents
# make sure NaN values for cat columns are filled before passing to load_data
#for c in categorical_cols:  
   #train_df.loc[:, c] = train_df.loc[:, c].astype(str).fillna("-9999999")
   #test_df.loc[:, c] = test_df.loc[:, c].astype(str).fillna("-9999999")

# %% [markdown]
# # Imaging + Echo(Categorical)

# %%
import pandas as pd
from transformers import AutoTokenizer,  set_seed
from MultimodalTab.load_multimodal_tabular_data import load_data_into_folds
set_seed(1234)
text_cols = ['heart_rate_rhc']

label_col = 'death_1y' 
categorical_cols = ['LV function', 'RV function', 'LA appearance',
       'RA dilated?', 'RA pressure range', 'Mitral regurgitation',
       'Tricuspid regurgitation', 'If PR, specify', 'Aortic regurgitation']
numerical_cols = [
 'heart_rate',
 'bsa',
 'lvedv',
 'lvedv_index',
 'lvesv',
 'lvesv_index',
 'lvsv',
 'lvsv_index',
 'lvco',
 'lvef',
 'lv_dia_mass',
 'lv_mass_index',
 'rvedv',
 'rvesv',
 'rvsv',
 'rvedv_index',
 'rvesv_index',
 'rvsv_index',
 'rvco',
 'rvef',
 'auto_lv_edv_index',
 'lv_edv',
 'auto_lv_esv_index',
 'lv_esv',
 'auto_lv_sv_index',
 'lv_sv',
 'auto_lv_co',
 'lv_ef',
 'auto_lv_mass_index',
 'lv_edm',
 'lv_esm',
 'auto_vmi',
 'auto_rv_edv_index',
 'rv_edv',
 'auto_rv_esv_index',
 'rv_esv',
 'auto_rv_sv_index',
 'rv_sv',
 'auto_rv_co',
 'rv_ef',
 'auto_rv_mass_index',
 'rv_edm',
 'rv_esm',
 'auto_percent_pred_rvesvi',
 'auto_percent_pred_rvedvi',
 'auto_percent_pred_rvef',
 'auto_percent_pred_rvsvi',
 'auto_percent_pred_rvedmi',
 'auto_percent_pred_lvesvi',
 'auto_percent_pred_lvedvi',
 'auto_percent_pred_lvef',
 'auto_percent_pred_lvsvi',
 'auto_percent_pred_lvedmi',
 'auto_percent_pred_vmi',
 'la_max_2ch_area',
 'la_min_2ch_area',
 'la_max_4ch_area',
 'la_min_4ch_area',
 'ra_max_2ch_area',
 'ra_min_2ch_area',
 'ra_max_4ch_area',
 'ra_min_4ch_area',
 'la_max_2ch_length',
 'la_min_2ch_length',
 'la_max_4ch_length',
 'la_min_4ch_length',
 'ra_max_2ch_length',
 'ra_min_2ch_length',
 'ra_max_4ch_length',
 'ra_min_4ch_length',
 'la_max_volume',
 'la_min_volume',
 'la_ejection_fraction',
 'la_long_axis_strain',
 'la_conduit_function',
 'ra_max_volume',
 'ra_min_volume',
 'ra_ejection_fraction',
 'ra_long_axis_strain',
 'ra_conduit_function',
 'la_max_volume_index',
 'la_min_volume_index',
 'la_ejection_fraction_index',
 'la_long_axis_strain_index',
 'ra_max_volume_index',
 'ra_min_volume_index',
 'ra_ejection_fraction_index',
 'ra_long_axis_strain_index',
 'pa_relative_area_change',
 'diastolic_pa_area',
 'systolic_pa_area',
 'pa_qflow_pos',
 'ao_qflow_positive',
 'EDD (34-56mm)',
 'PW (<12mm)',
 'IVS (<12mm)',
 'Max vel A wave (0.2-0.6 m/sec)',
 'Max vel E wave (0.4-1.0 m/sec)',
 'Sinus of Valsalva',
 'E/A Ratio. (old)',
 'Peak PG',
 'E/A Ratio']
label_list = ['Not Died', 'Died'] # what each label class represents
# make sure NaN values for cat columns are filled before passing to load_data
#for c in categorical_cols:  
   #train_df.loc[:, c] = train_df.loc[:, c].astype(str).fillna("-9999999")
   #test_df.loc[:, c] = test_df.loc[:, c].astype(str).fillna("-9999999")

# %% [markdown]
# # Imaging + Echo(Categorical+Text)

# %%
import pandas as pd
from transformers import AutoTokenizer,  set_seed
from MultimodalTab.load_multimodal_tabular_data import load_data_into_folds
set_seed(1234)
text_cols = ["E/e' average",'Machine (old)', 'Reported by 1',
       'Reporting Doctor', 'Summary', 'Conclusion', 'Scanned by 1','Machine','Scanned by 2']

label_col = 'death_1y' 
categorical_cols = ['LV function', 'RV function', 'LA appearance',
       'RA dilated?', 'RA pressure range', 'Mitral regurgitation',
       'Tricuspid regurgitation', 'If PR, specify', 'Aortic regurgitation']
numerical_cols = [
 'heart_rate',
 'bsa',
 'lvedv',
 'lvedv_index',
 'lvesv',
 'lvesv_index',
 'lvsv',
 'lvsv_index',
 'lvco',
 'lvef',
 'lv_dia_mass',
 'lv_mass_index',
 'rvedv',
 'rvesv',
 'rvsv',
 'rvedv_index',
 'rvesv_index',
 'rvsv_index',
 'rvco',
 'rvef',
 'auto_lv_edv_index',
 'lv_edv',
 'auto_lv_esv_index',
 'lv_esv',
 'auto_lv_sv_index',
 'lv_sv',
 'auto_lv_co',
 'lv_ef',
 'auto_lv_mass_index',
 'lv_edm',
 'lv_esm',
 'auto_vmi',
 'auto_rv_edv_index',
 'rv_edv',
 'auto_rv_esv_index',
 'rv_esv',
 'auto_rv_sv_index',
 'rv_sv',
 'auto_rv_co',
 'rv_ef',
 'auto_rv_mass_index',
 'rv_edm',
 'rv_esm',
 'auto_percent_pred_rvesvi',
 'auto_percent_pred_rvedvi',
 'auto_percent_pred_rvef',
 'auto_percent_pred_rvsvi',
 'auto_percent_pred_rvedmi',
 'auto_percent_pred_lvesvi',
 'auto_percent_pred_lvedvi',
 'auto_percent_pred_lvef',
 'auto_percent_pred_lvsvi',
 'auto_percent_pred_lvedmi',
 'auto_percent_pred_vmi',
 'la_max_2ch_area',
 'la_min_2ch_area',
 'la_max_4ch_area',
 'la_min_4ch_area',
 'ra_max_2ch_area',
 'ra_min_2ch_area',
 'ra_max_4ch_area',
 'ra_min_4ch_area',
 'la_max_2ch_length',
 'la_min_2ch_length',
 'la_max_4ch_length',
 'la_min_4ch_length',
 'ra_max_2ch_length',
 'ra_min_2ch_length',
 'ra_max_4ch_length',
 'ra_min_4ch_length',
 'la_max_volume',
 'la_min_volume',
 'la_ejection_fraction',
 'la_long_axis_strain',
 'la_conduit_function',
 'ra_max_volume',
 'ra_min_volume',
 'ra_ejection_fraction',
 'ra_long_axis_strain',
 'ra_conduit_function',
 'la_max_volume_index',
 'la_min_volume_index',
 'la_ejection_fraction_index',
 'la_long_axis_strain_index',
 'ra_max_volume_index',
 'ra_min_volume_index',
 'ra_ejection_fraction_index',
 'ra_long_axis_strain_index',
 'pa_relative_area_change',
 'diastolic_pa_area',
 'systolic_pa_area',
 'pa_qflow_pos',
 'ao_qflow_positive',
 'EDD (34-56mm)',
 'PW (<12mm)',
 'IVS (<12mm)',
 'Max vel A wave (0.2-0.6 m/sec)',
 'Max vel E wave (0.4-1.0 m/sec)',
 'Sinus of Valsalva',
 'E/A Ratio. (old)',
 'Peak PG',
 'E/A Ratio']
label_list = ['Not Died', 'Died'] # what each label class represents
# make sure NaN values for cat columns are filled before passing to load_data
#for c in categorical_cols:  
   #train_df.loc[:, c] = train_df.loc[:, c].astype(str).fillna("-9999999")
   #test_df.loc[:, c] = test_df.loc[:, c].astype(str).fillna("-9999999")

# %%
tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
train_dataset, val_dataset, test_dataset = load_data_into_folds(
    '/content/drive/MyDrive/Multimodal/all.csv',
    4,
    0.1,
    text_cols,
    tokenizer,
    label_col=label_col,
    label_list=label_list,
    categorical_cols=categorical_cols,
    numerical_cols=numerical_cols,
    sep_text_token_str=tokenizer.sep_token
)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:2593: UserWarning: n_quantiles (1000) is greater than the total number of samples (314). n_quantiles is set to n_samples.
#   "n_samples." % (self.n_quantiles, n_samples)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ...

# %%
import numpy as np
from scipy.special import softmax
from transformers import EvalPrediction
from sklearn import metrics
import seaborn as sns

import matplotlib.pyplot as plt
from sklearn.metrics import (
    auc,
    precision_recall_curve,
    roc_auc_score,
    f1_score,
    confusion_matrix,
    matthews_corrcoef,
)


def calc_classification_metrics(p: EvalPrediction):
  pred_labels = np.argmax(p.predictions, axis=1)
  pred_scores = softmax(p.predictions, axis=1)[:, 1]
  labels = p.label_ids
  if len(np.unique(labels)) == 2:  # binary classification
      roc_auc_pred_score = roc_auc_score(labels, pred_scores)
      precisions, recalls, thresholds = precision_recall_curve(labels,
                                                                pred_scores)
      fscore = (2 * precisions * recalls) / (precisions + recalls)
      fscore[np.isnan(fscore)] = 0
      ix = np.argmax(fscore)
      threshold = thresholds[ix].item()
      pr_auc = auc(recalls, precisions)
      tn, fp, fn, tp = confusion_matrix(labels, pred_labels, labels=[0, 1]).ravel()
      result = {'roc_auc': roc_auc_pred_score,
                'threshold': threshold,
                'AUPC': pr_auc,
                'recall': recalls[ix].item(),
                'precision': precisions[ix].item(), 'f1': fscore[ix].item(),
                'tn': tn.item(), 'fp': fp.item(), 'fn': fn.item(), 'tp': tp.item(),
                'sensitivity':(tp.item()/(tp.item()+fn.item())),
                'specificity':tn.item()/(tn.item()+fp.item()),
                'ppv':tp.item()/(tp.item()+fp.item()),
                'npv':tn.item()/(tn.item()+fn.item()),
                'accuracy':(tp.item()+tn.item())/(tp.item()+fp.item()+tn.item()+fn.item())
                }
      plt.figure(0).clf()
      plt.figure(figsize=(12,7))
      lw = 2
      fpr, tpr, thresh = metrics.roc_curve(labels, pred_scores)
      plt.plot(fpr,tpr,color="red",
          lw=lw,
          label="AUC = %0.2f" % roc_auc_pred_score,)
      plt.plot([0, 1], [0, 1], color="black", lw=lw, linestyle="--")
      plt.xlim([0.0, 1.0])
      plt.ylim([0.0, 1.05])
      sns.set(font_scale=1.5)
      plt.title("All Modality Features")
      plt.legend(loc="lower right")
      plt.xlabel('False Positive Rate')
      plt.ylabel('True Positive Rate')
      plt.xticks(size=20)
      plt.yticks(size=20)
      plt.show()
  else:
      acc = (pred_labels == labels).mean()
      f1 = f1_score(y_true=labels, y_pred=pred_labels)
      result = {
          "acc": acc,
          "f1": f1,
          "acc_and_f1": (acc + f1) / 2,
          "mcc": matthews_corrcoef(labels, pred_labels)
      }

  return result

# %% [markdown]
# # Training

# %%
from transformers import Trainer, TrainingArguments
import numpy as np
from MultimodalTab.tabular_modeling_auto import AutoModelWithTabular
from MultimodalTab.tabular_transformers import TabularConfig
from transformers import AutoConfig
from scipy.special import softmax
from sklearn import metrics
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import (
    auc,
    roc_auc_score,
    confusion_matrix
)
set_seed(1234)
k=1
tprs=[]
fprs=[]
aucs=[]

acc=[]
sen=[]
spec=[]
ppvs=[]
npvs=[]

for i,j in zip(train_dataset,test_dataset): 
    print("\n\nFold ",k)
    k=k+1
    num_labels = len(np.unique(i.labels))  
    config = AutoConfig.from_pretrained('bert-base-uncased')
    tabular_config = TabularConfig(
        num_labels=num_labels,
        cat_feat_dim=i.cat_feats.shape[1],
        numerical_feat_dim=i.numerical_feats.shape[1],
        combine_feat_method='weighted_feature_sum_on_transformer_cat_and_numerical_feats',
    )
    config.tabular_config = tabular_config

    model = AutoModelWithTabular.from_pretrained('bert-base-uncased', config=config)
    training_args = TrainingArguments(
        output_dir="/content/sample_data",
        logging_dir="/content/sample_data",
        overwrite_output_dir=True,
        do_train=True,
        do_eval=False,
        per_device_train_batch_size=8,
        num_train_epochs=3,
        evaluate_during_training=False,
        logging_steps=40
    )

    trainer= Trainer(
      model=model,
      args=training_args,
      train_dataset=i
    )
    trainer.train()

    base_fpr = np.linspace(0, 1, 101)
    pred=trainer.predict(j)

    pred_labels = np.argmax(pred.predictions, axis=1)

    pred_scores=softmax(pred[0], axis=1)[:, 1]
    labels = pred.label_ids
    fpr, tpr, _ = metrics.roc_curve(labels, pred_scores)

    tpr = np.interp(base_fpr, fpr, tpr)
    tpr[0] = 0.0
    tprs.append(tpr)

    roc_auc_pred_score = roc_auc_score(labels, pred_scores )
    tn, fp, fn, tp = confusion_matrix(labels, pred_labels, labels=[0, 1]).ravel()
    sensitivity = (tp.item())/(tp.item()+fn.item())
    specificity = tn.item()/(tn.item()+fp.item())
    ppv = tp.item()/(tp.item()+fp.item())
    npv = tn.item()/(tn.item()+fn.item())
    accuracy = (tp.item()+tn.item())/(tp.item()+fp.item()+tn.item()+fn.item())


    fprs.append(fpr)
    aucs.append(roc_auc_pred_score)
    acc.append(accuracy)
    sen.append(sensitivity)
    spec.append(specificity)
    ppvs.append(ppv)
    npvs.append(npv)
# Out:
# Fold  1
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertWithTabular: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertWithTabular from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPretraining model).
# - This IS NOT expected if you are initializing BertWithTabular from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %% [markdown]
# # Demographic Mean ROC

# %%
print("Mean Accuracy %0.2f\u00B1%0.2f" % (np.mean(acc), np.std(acc)))
print("Mean Sensitivity %0.2f\u00B1%0.2f" % (np.mean(sen), np.std(sen)))
print("Mean Specificity %0.2f\u00B1%0.2f" % (np.mean(spec), np.std(spec)))
print("Mean PPV %0.2f\u00B1%0.2f" % (np.mean(ppvs), np.std(ppvs)))
print("Mean NPV %0.2f\u00B1%0.2f" % (np.mean(npvs), np.std(npvs)))



fig, ax = plt.subplots(figsize=(20,15))

ax.plot([0, 1], [0, 1], linestyle="--", lw=5, color="r", label="Chance", alpha=0.8)
tprs = np.array(tprs)
mean_tprs_1 = tprs.mean(axis=0)

mean_auc_1 = auc(base_fpr, mean_tprs_1)
std_auc = np.std(aucs)

ax.plot(
    base_fpr,
    mean_tprs_1,
    color="b",
    label=r"Demograpgic Mean ROC (AUC = %0.2f $\pm$ %0.2f)" % (mean_auc_1, std_auc),
    lw=5,
    alpha=0.8,
)


std = tprs.std(axis=0)

tprs_upper = np.minimum(mean_tprs_1 + std, 1)
tprs_lower = mean_tprs_1 - std

ax.fill_between(base_fpr, tprs_lower, tprs_upper, color='grey', alpha=0.3,label=r"$\pm$ 1 std. dev.",)

ax.set(
    xlim=[-0.05, 1.05],
    ylim=[-0.05, 1.05],
    title="",
)
sns.set(font_scale=1.5)
ax.tick_params(axis='both', labelsize=30)
plt.ylabel('True Positive Rate',fontsize=30)
plt.xlabel('False Positive Rate',fontsize=30)
ax.legend(loc="lower right",fontsize=17)
plt.show()
# Out:
# Mean Accuracy 0.65±0.03
# Mean Sensitivity 0.58±0.07
# Mean Specificity 0.74±0.02
# Mean PPV 0.74±0.01
# Mean NPV 0.58±0.04

# %% [markdown]
# # Echo Report (Categorical) Mean ROC

# %%
print("Mean Accuracy %0.2f\u00B1%0.2f" % (np.mean(acc), np.std(acc)))
print("Mean Sensitivity %0.2f\u00B1%0.2f" % (np.mean(sen), np.std(sen)))
print("Mean Specificity %0.2f\u00B1%0.2f" % (np.mean(spec), np.std(spec)))
print("Mean PPV %0.2f\u00B1%0.2f" % (np.mean(ppvs), np.std(ppvs)))
print("Mean NPV %0.2f\u00B1%0.2f" % (np.mean(npvs), np.std(npvs)))



fig, ax = plt.subplots(figsize=(20,15))

ax.plot([0, 1], [0, 1], linestyle="--", lw=5, color="r", label="Chance", alpha=0.8)
tprs = np.array(tprs)
mean_tprs_2 = tprs.mean(axis=0)

mean_auc_2 = auc(base_fpr, mean_tprs_2)
std_auc = np.std(aucs)

ax.plot(
    base_fpr,
    mean_tprs_2,
    color="b",
    label=r"Echo Report (Categorical) Mean ROC (AUC = %0.2f $\pm$ %0.2f)" % (mean_auc_2, std_auc),
    lw=5,
    alpha=0.8,
)


std = tprs.std(axis=0)

tprs_upper = np.minimum(mean_tprs_2 + std, 1)
tprs_lower = mean_tprs_2 - std

ax.fill_between(base_fpr, tprs_lower, tprs_upper, color='grey', alpha=0.3,label=r"$\pm$ 1 std. dev.",)

ax.set(
    xlim=[-0.05, 1.05],
    ylim=[-0.05, 1.05],
    title="",
)
sns.set(font_scale=1.5)
ax.tick_params(axis='both', labelsize=30)
plt.ylabel('True Positive Rate',fontsize=30)
plt.xlabel('False Positive Rate',fontsize=30)
ax.legend(loc="lower right",fontsize=17)
plt.show()
# Out:
# Mean Accuracy 0.59±0.01
# Mean Sensitivity 0.54±0.05
# Mean Specificity 0.67±0.05
# Mean PPV 0.68±0.02
# Mean NPV 0.53±0.01

# %% [markdown]
# # Echo Report (Text) Mean ROC

# %%
print("Mean Accuracy %0.2f\u00B1%0.2f" % (np.mean(acc), np.std(acc)))
print("Mean Sensitivity %0.2f\u00B1%0.2f" % (np.mean(sen), np.std(sen)))
print("Mean Specificity %0.2f\u00B1%0.2f" % (np.mean(spec), np.std(spec)))
print("Mean PPV %0.2f\u00B1%0.2f" % (np.mean(ppvs), np.std(ppvs)))
print("Mean NPV %0.2f\u00B1%0.2f" % (np.mean(npvs), np.std(npvs)))



fig, ax = plt.subplots(figsize=(20,15))

ax.plot([0, 1], [0, 1], linestyle="--", lw=5, color="r", label="Chance", alpha=0.8)
tprs = np.array(tprs)
mean_tprs_3 = tprs.mean(axis=0)

mean_auc_3 = auc(base_fpr, mean_tprs_3)
std_auc = np.std(aucs)

ax.plot(
    base_fpr,
    mean_tprs_3,
    color="b",
    label=r"Echo Report (Text) Mean ROC (AUC = %0.2f $\pm$ %0.2f)" % (mean_auc_3, std_auc),
    lw=5,
    alpha=0.8,
)


std = tprs.std(axis=0)

tprs_upper = np.minimum(mean_tprs_3 + std, 1)
tprs_lower = mean_tprs_3 - std

ax.fill_between(base_fpr, tprs_lower, tprs_upper, color='grey', alpha=0.3,label=r"$\pm$ 1 std. dev.",)

ax.set(
    xlim=[-0.05, 1.05],
    ylim=[-0.05, 1.05],
    title="",
)
sns.set(font_scale=1.5)
ax.tick_params(axis='both', labelsize=30)
plt.ylabel('True Positive Rate',fontsize=30)
plt.xlabel('False Positive Rate',fontsize=30)
ax.legend(loc="lower right",fontsize=17)
plt.show()
# Out:
# Mean Accuracy 0.64±0.05
# Mean Sensitivity 0.59±0.12
# Mean Specificity 0.71±0.05
# Mean PPV 0.72±0.02
# Mean NPV 0.59±0.07

# %% [markdown]
# # Echo Report (Text+Categorical) Mean ROC

# %%
print("Mean Accuracy %0.2f\u00B1%0.2f" % (np.mean(acc), np.std(acc)))
print("Mean Sensitivity %0.2f\u00B1%0.2f" % (np.mean(sen), np.std(sen)))
print("Mean Specificity %0.2f\u00B1%0.2f" % (np.mean(spec), np.std(spec)))
print("Mean PPV %0.2f\u00B1%0.2f" % (np.mean(ppvs), np.std(ppvs)))
print("Mean NPV %0.2f\u00B1%0.2f" % (np.mean(npvs), np.std(npvs)))



fig, ax = plt.subplots(figsize=(20,15))

ax.plot([0, 1], [0, 1], linestyle="--", lw=5, color="r", label="Chance", alpha=0.8)
tprs = np.array(tprs)
mean_tprs_4 = tprs.mean(axis=0)

mean_auc_4 = auc(base_fpr, mean_tprs_4)
std_auc = np.std(aucs)

ax.plot(
    base_fpr,
    mean_tprs_4,
    color="b",
    label=r"Echo Report (Text+Categorical) Mean ROC (AUC = %0.2f $\pm$ %0.2f)" % (mean_auc_4, std_auc),
    lw=5,
    alpha=0.8,
)


std = tprs.std(axis=0)

tprs_upper = np.minimum(mean_tprs_4 + std, 1)
tprs_lower = mean_tprs_4 - std

ax.fill_between(base_fpr, tprs_lower, tprs_upper, color='grey', alpha=0.3,label=r"$\pm$ 1 std. dev.",)

ax.set(
    xlim=[-0.05, 1.05],
    ylim=[-0.05, 1.05],
    title="",
)
sns.set(font_scale=1.5)
ax.tick_params(axis='both', labelsize=30)
plt.ylabel('True Positive Rate',fontsize=30)
plt.xlabel('False Positive Rate',fontsize=30)
ax.legend(loc="lower right",fontsize=17)
plt.show()
# Out:
# Mean Accuracy 0.65±0.02
# Mean Sensitivity 0.52±0.04
# Mean Specificity 0.82±0.02
# Mean PPV 0.78±0.02
# Mean NPV 0.57±0.02

# %% [markdown]
# # Numerical Imaging Fetaures Mean ROC

# %%
print("Mean Accuracy %0.2f\u00B1%0.2f" % (np.mean(acc), np.std(acc)))
print("Mean Sensitivity %0.2f\u00B1%0.2f" % (np.mean(sen), np.std(sen)))
print("Mean Specificity %0.2f\u00B1%0.2f" % (np.mean(spec), np.std(spec)))
print("Mean PPV %0.2f\u00B1%0.2f" % (np.mean(ppvs), np.std(ppvs)))
print("Mean NPV %0.2f\u00B1%0.2f" % (np.mean(npvs), np.std(npvs)))



fig, ax = plt.subplots(figsize=(20,15))

ax.plot([0, 1], [0, 1], linestyle="--", lw=5, color="r", label="Chance", alpha=0.8)
tprs = np.array(tprs)
mean_tprs_5 = tprs.mean(axis=0)

mean_auc_5 = auc(base_fpr, mean_tprs_5)
std_auc = np.std(aucs)

ax.plot(
    base_fpr,
    mean_tprs_5,
    color="b",
    label=r"Imaging(Numerical) Mean ROC (AUC = %0.2f $\pm$ %0.2f)" % (mean_auc_5, std_auc),
    lw=5,
    alpha=0.8,
)


std = tprs.std(axis=0)

tprs_upper = np.minimum(mean_tprs_5 + std, 1)
tprs_lower = mean_tprs_5 - std

ax.fill_between(base_fpr, tprs_lower, tprs_upper, color='grey', alpha=0.3,label=r"$\pm$ 1 std. dev.",)

ax.set(
    xlim=[-0.05, 1.05],
    ylim=[-0.05, 1.05],
    title="",
)
sns.set(font_scale=1.5)
ax.tick_params(axis='both', labelsize=30)
plt.ylabel('True Positive Rate',fontsize=30)
plt.xlabel('False Positive Rate',fontsize=30)
ax.legend(loc="lower right",fontsize=17)
plt.show()
# Out:
# Mean Accuracy 0.76±0.03
# Mean Sensitivity 0.69±0.06
# Mean Specificity 0.86±0.06
# Mean PPV 0.87±0.05
# Mean NPV 0.69±0.04

# %% [markdown]
# ## Imaging + Echo(Text) Mean ROC

# %%
print("Mean Accuracy %0.2f\u00B1%0.2f" % (np.mean(acc), np.std(acc)))
print("Mean Sensitivity %0.2f\u00B1%0.2f" % (np.mean(sen), np.std(sen)))
print("Mean Specificity %0.2f\u00B1%0.2f" % (np.mean(spec), np.std(spec)))
print("Mean PPV %0.2f\u00B1%0.2f" % (np.mean(ppvs), np.std(ppvs)))
print("Mean NPV %0.2f\u00B1%0.2f" % (np.mean(npvs), np.std(npvs)))



fig, ax = plt.subplots(figsize=(20,15))

ax.plot([0, 1], [0, 1], linestyle="--", lw=5, color="r", label="Chance", alpha=0.8)
tprs = np.array(tprs)
mean_tprs_6 = tprs.mean(axis=0)

mean_auc_6 = auc(base_fpr, mean_tprs_6)
std_auc = np.std(aucs)

ax.plot(
    base_fpr,
    mean_tprs_6,
    color="b",
    label=r"Imaging(Numerical) + Echo(Text) Mean ROC (AUC = %0.2f $\pm$ %0.2f)" % (mean_auc_6, std_auc),
    lw=5,
    alpha=0.8,
)


std = tprs.std(axis=0)

tprs_upper = np.minimum(mean_tprs_6 + std, 1)
tprs_lower = mean_tprs_6 - std

ax.fill_between(base_fpr, tprs_lower, tprs_upper, color='grey', alpha=0.3,label=r"$\pm$ 1 std. dev.",)

ax.set(
    xlim=[-0.05, 1.05],
    ylim=[-0.05, 1.05],
    title="",
)
sns.set(font_scale=1.5)
ax.tick_params(axis='both', labelsize=30)
plt.ylabel('True Positive Rate',fontsize=30)
plt.xlabel('False Positive Rate',fontsize=30)
ax.legend(loc="lower right",fontsize=17)
plt.show()
# Out:
# Mean Accuracy 0.78±0.01
# Mean Sensitivity 0.69±0.03
# Mean Specificity 0.90±0.03
# Mean PPV 0.90±0.03
# Mean NPV 0.70±0.01

# %% [markdown]
# # Imaging + Echo(Categorical) Mean ROC

# %%
print("Mean Accuracy %0.2f\u00B1%0.2f" % (np.mean(acc), np.std(acc)))
print("Mean Sensitivity %0.2f\u00B1%0.2f" % (np.mean(sen), np.std(sen)))
print("Mean Specificity %0.2f\u00B1%0.2f" % (np.mean(spec), np.std(spec)))
print("Mean PPV %0.2f\u00B1%0.2f" % (np.mean(ppvs), np.std(ppvs)))
print("Mean NPV %0.2f\u00B1%0.2f" % (np.mean(npvs), np.std(npvs)))



fig, ax = plt.subplots(figsize=(20,15))

ax.plot([0, 1], [0, 1], linestyle="--", lw=5, color="r", label="Chance", alpha=0.8)
tprs = np.array(tprs)
mean_tprs_7 = tprs.mean(axis=0)

mean_auc_7 = auc(base_fpr, mean_tprs_7)
std_auc = np.std(aucs)

ax.plot(
    base_fpr,
    mean_tprs_7,
    color="b",
    label=r"Imaging(Numerical) + Echo(Categorical) Mean ROC (AUC = %0.2f $\pm$ %0.2f)" % (mean_auc_7, std_auc),
    lw=5,
    alpha=0.8,
)


std = tprs.std(axis=0)

tprs_upper = np.minimum(mean_tprs_7 + std, 1)
tprs_lower = mean_tprs_7 - std

ax.fill_between(base_fpr, tprs_lower, tprs_upper, color='grey', alpha=0.3,label=r"$\pm$ 1 std. dev.",)

ax.set(
    xlim=[-0.05, 1.05],
    ylim=[-0.05, 1.05],
    title="",
)
sns.set(font_scale=1.5)
ax.tick_params(axis='both', labelsize=30)
plt.ylabel('True Positive Rate',fontsize=30)
plt.xlabel('False Positive Rate',fontsize=30)
ax.legend(loc="lower right",fontsize=17)
plt.show()
# Out:
# Mean Accuracy 0.75±0.02
# Mean Sensitivity 0.67±0.03
# Mean Specificity 0.85±0.02
# Mean PPV 0.85±0.02
# Mean NPV 0.67±0.02

# %% [markdown]
# # Imaging + Echo(Categorical+Text) Mean ROC

# %%
print("Mean Accuracy %0.2f\u00B1%0.2f" % (np.mean(acc), np.std(acc)))
print("Mean Sensitivity %0.2f\u00B1%0.2f" % (np.mean(sen), np.std(sen)))
print("Mean Specificity %0.2f\u00B1%0.2f" % (np.mean(spec), np.std(spec)))
print("Mean PPV %0.2f\u00B1%0.2f" % (np.mean(ppvs), np.std(ppvs)))
print("Mean NPV %0.2f\u00B1%0.2f" % (np.mean(npvs), np.std(npvs)))



fig, ax = plt.subplots(figsize=(20,15))

ax.plot([0, 1], [0, 1], linestyle="--", lw=5, color="r", label="Chance", alpha=0.8)
tprs = np.array(tprs)
mean_tprs_8 = tprs.mean(axis=0)

mean_auc_8 = auc(base_fpr, mean_tprs_8)
std_auc = np.std(aucs)

ax.plot(
    base_fpr,
    mean_tprs_8,
    color="b",
    label=r"Imaging(Numerical) + Echo(Categorical+Text) Mean ROC (AUC = %0.2f $\pm$ %0.2f)" % (mean_auc_8, std_auc),
    lw=5,
    alpha=0.8,
)


std = tprs.std(axis=0)

tprs_upper = np.minimum(mean_tprs_8 + std, 1)
tprs_lower = mean_tprs_8 - std

ax.fill_between(base_fpr, tprs_lower, tprs_upper, color='grey', alpha=0.3,label=r"$\pm$ 1 std. dev.",)

ax.set(
    xlim=[-0.05, 1.05],
    ylim=[-0.05, 1.05],
    title="",
)
sns.set(font_scale=1.5)
ax.tick_params(axis='both', labelsize=30)
plt.ylabel('True Positive Rate',fontsize=30)
plt.xlabel('False Positive Rate',fontsize=30)
ax.legend(loc="lower right",fontsize=17)
plt.show()
# Out:
# Mean Accuracy 0.80±0.01
# Mean Sensitivity 0.73±0.05
# Mean Specificity 0.89±0.03
# Mean PPV 0.90±0.02
# Mean NPV 0.72±0.03

# %% [markdown]
# # All Result Together

# %%
df=pd.read_csv('/content/drive/MyDrive/Multimodal/all.csv',low_memory=False)
df.head()
# Out:
#    mri_order  age  who_functional_class  survival_time  death_1y  \
# 0          1   77                   3.0            319         1
# 1          0   48                   2.0             46         1
# 2          0   57                   3.0              6         1
# 3          0   76                   2.0            313         1
# 4          2   70                   3.0             55         1
#
#    overall_death  survival_iloprost_time  death_iloprost_1y  heart_rate_rhc  \
# 0              1                     319                  1       67.037103
# 1              1                      46                  1       61.000000
# 2              1                       6                  1       79.214261
# 3              1                     313                  1       70.000000
# 4              1                      55                  1       71.049710
#
#    walking_distance  ...                                       E/e' average  \
# ...

# %%
from sklearn.model_selection import train_test_split
df=df.loc[df['final_primary_ph_diagnosis'] == 'PAH']
data=df['reveal_score']+6
labels=df['death_1y']
all= pd.concat([data], axis=1)
from imblearn.under_sampling import RandomUnderSampler

undersample = RandomUnderSampler(sampling_strategy='majority')
X_over, y_over = undersample.fit_resample(all, labels)
x_train, x_test, y_train, y_test = train_test_split(X_over, y_over, shuffle=True, train_size = 0.70,stratify=y_over)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
dt = DecisionTreeClassifier(criterion='entropy',random_state=0)
dt.fit(x_train, y_train)
print("Accuracy on training set: {:.3f}".format(dt.score(x_train, y_train)))
print("Accuracy on test set: {:.3f}".format(dt.score(x_test, y_test)))
#Plot ROC chart for DT.Write your code below.

y_pred = dt.predict(x_test)
pre_probs1 = dt.predict_proba(x_test)

pre_probs1 = pre_probs1[:, 1]


pre_fpr, pre_tpr, _ = roc_curve(y_test, pre_probs1)
# plot the roc curve for the model
auc=roc_auc_score(y_test, y_pred)
print('AUC=',auc)
plt.figure(figsize=(12,7))
lw=2
plt.plot(pre_fpr, pre_tpr,color="red",
          lw=lw,
          label="AUC = %0.2f" % auc,)
# axis labels
plt.plot([0, 1], [0, 1], color="black", lw=lw, linestyle="--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
sns.set(font_scale=1.5)
#plt.title("Reveal Feature")
plt.legend(loc="lower right")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.xticks(size=20)
plt.yticks(size=20)
# show the legend
plt.legend()
# show the plot
plt.show()
# Out:
# Accuracy on training set: 0.626
# Accuracy on test set: 0.679
# AUC= 0.6785714285714286

# %%
plt.figure(0).clf()
plt.figure(figsize=(17,12))
lw=5

plt.plot(pre_fpr, pre_tpr,color="hotpink",lw=lw,label="AUC %0.2f\u00B10.01 for Reveal (baseline)" % auc,)
plt.plot(base_fpr,mean_tprs_1,color="purple",lw=lw,label="AUC %0.2f\u00B10.01 for Demographic (Bi-modal)" % mean_auc_1,)
plt.plot(base_fpr,mean_tprs_2,color="green",lw=lw,label="AUC %0.2f\u00B10.01 for Echo Report (Categorical) (Unimodal)" % mean_auc_2,)
plt.plot(base_fpr,mean_tprs_3,color="orange",lw=lw,label="AUC %0.2f\u00B10.04 for Echo Report (Text) (Unimodal)" % mean_auc_3,)
plt.plot(base_fpr,mean_tprs_4,color="brown",lw=lw,label="AUC %0.2f\u00B10.03 for Echo Report (Text + categorical) (Bi-modal)" % mean_auc_4,)
plt.plot(base_fpr,mean_tprs_5,color="blue",lw=lw,label="AUC %0.2f\u00B10.02 for Imaging Measurements (Unimodal)" % mean_auc_5,)
plt.plot(base_fpr,mean_tprs_6,color="magenta",lw=lw,label="AUC %0.2f\u00B10.01 for Imaging Measurements + Echo Report (Text) (Bi-modal)" % mean_auc_6,)
plt.plot(base_fpr,mean_tprs_7,color="lightseagreen",lw=lw,label="AUC %0.2f\u00B10.01 for Imaging Measurements + Echo Report (Categorical) (Bi-modal)" % mean_auc_7,)
plt.plot(base_fpr,mean_tprs_8,color="red",lw=lw,label="AUC %0.2f\u00B10.01 for Imaging Measurements + Echo Report (Text + Categorical) (Tri-modal)" % mean_auc_8,)
plt.plot([0, 1], [0, 1], color="black", lw=lw, linestyle="--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
sns.set(font_scale=1.5)
#plt.title("Receiver operating characteristic curve",fontsize=30)
plt.legend(loc="lower right",fontsize=13.3)
plt.xlabel('False Positive Rate',fontsize=30)
plt.ylabel('True Positive Rate',fontsize=30)
plt.xticks(size=30)
plt.yticks(size=30)
plt.show()
